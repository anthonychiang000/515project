# %%
import numpy as np
import math
import GPy
import matplotlib.pyplot as plt
import seaborn

# %%
def generate_data():
    data = np.loadtxt('./../lda.csv', delimiter=",")
    sample = np.random.choice(data.shape[0], size = 32, replace=False)
    samp_data = data[sample]
    #X = samp_data[:, :-1]
    #y = samp_data[:, -1].reshape(-1, 1)
    X = samp_data[:, :-1]
    y = samp_data[:, -1].reshape(-1, 1)
    return X, y

X, y = generate_data()
y = np.log10(y)

# %%
def base_kernel_search(X, y):
    kernel_comp = [GPy.kern.RBF(input_dim=X.shape[1], variance=1.0, lengthscale=1.0, useGPU=True), 
                         GPy.kern.RatQuad(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern32(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern52(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.StdPeriodic(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0, useGPU = True),
                         GPy.kern.Exponential(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0)]
    
    best_model = None
    best_bic = float('inf')
    mean = GPy.mappings.Constant(input_dim = X.shape[1], output_dim = 1, value = np.mean(y))


    for kernel1 in kernel_comp:
        kernel = kernel1
        model = GPy.models.GPRegression(X, y, kernel, noise_var=0.001**2, mean_function=mean)
        model.Gaussian_noise.variance.fix()
        model.optimize_restarts(5, verbose=False)
        n = model.num_data
        k = len(model.parameters)
        log_likelihood = model.log_likelihood()
        
        bic = k * np.log(n) - 2 * log_likelihood
        print(bic)
        print(model)

        if bic < best_bic:
            best_model = (kernel, model)
            best_bic = bic

    print(best_bic, best_model)

# %%
import warnings
with warnings.catch_warnings(action="ignore"):
    base_kernel_search(X, y)
# Out:
# -4.416176917381449
#
# Name : GP regression
# Objective : -7.406692312890314
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |     4.261026438748114  |               |
#   rbf.variance             |  0.036852839015622384  |      +ve      |
#   rbf.lengthscale          |    0.4497793983532726  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# -6.136531548096048
#
# Name : GP regression
# Objective : -8.266869628247614
# Number of Parameters : 5
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |   4.2845883154181825  |               |
#   RatQuad.variance         |  0.03745393500703986  |      +ve      |
#   RatQuad.lengthscale      |   0.2116426532783505  |      +ve      |
#   RatQuad.power            |  0.14993858755911774  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# -4.416176901361865
#
# Name : GP regression
# Objective : -7.406692304880522
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261025947677378  |               |
#   Mat32.variance           |  0.03685311710943425  |      +ve      |
#   Mat32.lengthscale        |  0.26221968486483976  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# -4.4161768784283595
#
# Name : GP regression
# Objective : -7.406692293413769
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261025087718214  |               |
#   Mat52.variance           |  0.03685233391942086  |      +ve      |
#   Mat52.lengthscale        |    0.318454390729603  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# -6.578449460227187
#
# Name : GP regression
# Objective : -8.487828584313183
# Number of Parameters : 5
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   GP_regression.            |                value  |  constraints  |  priors
#   constmap.C                |   4.2793673565016315  |               |
#   std_periodic.variance     |  0.03702658730800315  |      +ve      |
#   std_periodic.period       |   2.0314296647564736  |      +ve      |
#   std_periodic.lengthscale  |  0.29525941689348034  |      +ve      |
#   Gaussian_noise.variance   |                1e-06  |   +ve fixed   |
# -4.561113775605563
#
# Name : GP regression
# Objective : -7.479160742002371
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.266245257080198  |               |
#   Exponential.variance     |  0.03691217487938309  |      +ve      |
#   Exponential.lengthscale  |   3.1768023208761003  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# -6.578449460227187 (<GPy.kern.src.standard_periodic.StdPeriodic object at 0x7f29d40e12d0>, <GPy.models.gp_regression.GPRegression object at 0x7f29d425ea50>)

# %%
def kernel_search(X, y):
    kernel_comp = [GPy.kern.RBF(input_dim=X.shape[1], variance=1.0, lengthscale=1.0), 
                         GPy.kern.RatQuad(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern32(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern52(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.StdPeriodic(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Exponential(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0)]
    
    best_model = None
    best_bic = float('inf')
    mean_comp = [GPy.mappings.Constant(input_dim = X.shape[1], output_dim = 1, value = np.mean(y)), 
            GPy.mappings.Linear(input_dim = X.shape[1], output_dim = 1)]


    for kernel1 in kernel_comp:
        for kernel2 in kernel_comp:
            for mean in mean_comp:
                # Combine kernels
                kernel = kernel1 * kernel2
                model = GPy.models.GPRegression(X, y, kernel, noise_var=0.001**2, mean_function=mean)
                model.Gaussian_noise.variance.fix()
                model.optimize()
                n = model.num_data
                k = len(model.optimizer_array)
                log_likelihood = model.log_likelihood()
                
                bic = k * np.log(n) - 2 * log_likelihood
                print(bic)
                print(model)

                if bic < best_bic:
                    best_model = (kernel, model)
                    best_bic = bic

    print(best_bic, best_model)

# %%
import warnings
with warnings.catch_warnings(action="ignore"):
    kernel_search(X, y)
# Out:
# 2.515331252997786
#
# Name : GP regression
# Objective : -7.406674130500424
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   constmap.C               |   4.261028162874061  |               |
#   mul.rbf.variance         |  0.1919710055300377  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999578079655745  |      +ve      |
#   mul.rbf_1.variance       |  0.1919710055300377  |      +ve      |
#   mul.rbf_1.lengthscale    |  0.9999578079655745  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 82.90711489847097
#
# Name : GP regression
# Objective : 27.590613838036578
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |  0.5730783209082795  |      +ve      |
#   mul.rbf.lengthscale      |    1.00014297814749  |      +ve      |
#   mul.rbf_1.variance       |  0.5730783209082795  |      +ve      |
#   mul.rbf_1.lengthscale    |    1.00014297814749  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.981165021693954
#
# Name : GP regression
# Objective : -7.406625197552202
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   constmap.C               |   4.261027491823535  |               |
#   mul.rbf.variance         |   0.191971264397047  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999421056954836  |      +ve      |
#   mul.RatQuad.variance     |   0.191971264397047  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999801337932377  |      +ve      |
#   mul.RatQuad.power        |  2.0000197754104616  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 86.3735732502047
#
# Name : GP regression
# Objective : 27.59097506250358
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |   0.573084495657447  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999260251158022  |      +ve      |
#   mul.RatQuad.variance     |   0.573084495657447  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999746335140467  |      +ve      |
#   mul.RatQuad.power        |   2.000025255200337  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 2.5152949119310186
#
# Name : GP regression
# Objective : -7.406692301033807
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261026318913517  |               |
#   mul.rbf.variance         |  0.19197058124055472  |      +ve      |
#   mul.rbf.lengthscale      |   0.6245372469018257  |      +ve      |
#   mul.Mat32.variance       |  0.19197058124055472  |      +ve      |
#   mul.Mat32.lengthscale    |   0.8092487628774417  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 82.90783342340649
#
# Name : GP regression
# Objective : 27.59097310050434
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |  0.5730841831739485  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999263123159746  |      +ve      |
#   mul.Mat32.variance       |  0.5730841831739485  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9999653767907115  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 2.515400073871362
#
# Name : GP regression
# Objective : -7.406639720063636
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261026848134805  |               |
#   mul.rbf.variance         |  0.19197173768949183  |      +ve      |
#   mul.rbf.lengthscale      |   0.9999567718819582  |      +ve      |
#   mul.Mat52.variance       |  0.19197173768949183  |      +ve      |
#   mul.Mat52.lengthscale    |   0.9999761884747922  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 82.90762238996501
#
# Name : GP regression
# Objective : 27.5908675837836
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |  0.5730824602512296  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999420549474765  |      +ve      |
#   mul.Mat52.variance       |  0.5730824602512296  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9999680835039734  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.981030982571031
#
# Name : GP regression
# Objective : -7.4066922171136635
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   4.2610298675486185  |               |
#   mul.rbf.variance              |  0.19197099056034742  |      +ve      |
#   mul.rbf.lengthscale           |   0.5892538519226895  |      +ve      |
#   mul.std_periodic.variance     |  0.19197099056034683  |      +ve      |
#   mul.std_periodic.period       |   0.9008268860286647  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.9483998285956337  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.39237165334023
#
# Name : GP regression
# Objective : 27.60037426407135
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.rbf.variance              |  0.5732508515523932  |      +ve      |
#   mul.rbf.lengthscale           |   0.998504132243873  |      +ve      |
#   mul.std_periodic.variance     |  0.5732508515523932  |      +ve      |
#   mul.std_periodic.period       |   0.999688125770301  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9998379745338731  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 2.5152949749478175
#
# Name : GP regression
# Objective : -7.406692269525408
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |    4.261026653202942  |               |
#   mul.rbf.variance             |  0.19196882780793956  |      +ve      |
#   mul.rbf.lengthscale          |   0.6289539298923582  |      +ve      |
#   mul.Exponential.variance     |  0.19196882780793956  |      +ve      |
#   mul.Exponential.lengthscale  |     0.86847744381253  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 82.90835217293589
#
# Name : GP regression
# Objective : 27.59123247526904
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.rbf.variance             |  0.5730885430305956  |      +ve      |
#   mul.rbf.lengthscale          |  0.9998876475580656  |      +ve      |
#   mul.Exponential.variance     |  0.5730885430305956  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999638614462514  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 5.981030806575383
#
# Name : GP regression
# Objective : -7.406692305111488
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261026539747645  |               |
#   mul.RatQuad.variance     |  0.19197101168177377  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.8515891681182813  |      +ve      |
#   mul.RatQuad.power        |    2.156678004241109  |      +ve      |
#   mul.rbf.variance         |  0.19197101168177377  |      +ve      |
#   mul.rbf.lengthscale      |   0.6089984986217022  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 86.37357337659799
#
# Name : GP regression
# Objective : 27.590975125700226
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.RatQuad.variance     |  0.5730847449681294  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999746379611962  |      +ve      |
#   mul.RatQuad.power        |  2.0000252507587377  |      +ve      |
#   mul.rbf.variance         |  0.5730847449681294  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999260380779889  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 9.446766864033549
#
# Name : GP regression
# Objective : -7.406692227782269
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.             |                value  |  constraints  |  priors
#   constmap.C                 |    4.261024608934861  |               |
#   mul.RatQuad.variance       |  0.19197183508722152  |      +ve      |
#   mul.RatQuad.lengthscale    |   0.5175708147935406  |      +ve      |
#   mul.RatQuad.power          |   2.5446677671383826  |      +ve      |
#   mul.RatQuad_1.variance     |  0.19197183508722152  |      +ve      |
#   mul.RatQuad_1.lengthscale  |   0.5175708147935406  |      +ve      |
#   mul.RatQuad_1.power        |   2.5446677671383826  |      +ve      |
#   Gaussian_noise.variance    |                1e-06  |   +ve fixed   |
# 89.84190887373526
#
# Name : GP regression
# Objective : 27.592274922868995
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.             |               value  |  constraints  |  priors
#   linmap.A                   |              (4, 1)  |               |
#   mul.RatQuad.variance       |  0.5731055384472825  |      +ve      |
#   mul.RatQuad.lengthscale    |  0.9999083872396046  |      +ve      |
#   mul.RatQuad.power          |  2.0000905583184188  |      +ve      |
#   mul.RatQuad_1.variance     |  0.5731055384472825  |      +ve      |
#   mul.RatQuad_1.lengthscale  |  0.9999083872396046  |      +ve      |
#   mul.RatQuad_1.power        |  2.0000905583184188  |      +ve      |
#   Gaussian_noise.variance    |               1e-06  |   +ve fixed   |
# 5.9810308319251035
#
# Name : GP regression
# Objective : -7.406692292436627
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |     4.26102395562655  |               |
#   mul.RatQuad.variance     |  0.19197111683411597  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.5525540628647111  |      +ve      |
#   mul.RatQuad.power        |   2.5367197275069473  |      +ve      |
#   mul.Mat32.variance       |  0.19197111683411597  |      +ve      |
#   mul.Mat32.lengthscale    |  0.44875786513890586  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 86.37620803119702
#
# Name : GP regression
# Objective : 27.592292452999747
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.RatQuad.variance     |  0.5731080886008088  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999073300874767  |      +ve      |
#   mul.RatQuad.power        |  2.0000920660132877  |      +ve      |
#   mul.Mat32.variance       |  0.5731080886008088  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9998734706361938  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.9810308126112375
#
# Name : GP regression
# Objective : -7.40669230209356
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261025791123811  |               |
#   mul.RatQuad.variance     |  0.19197042264117684  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.6178014705309189  |      +ve      |
#   mul.RatQuad.power        |     2.44616398974467  |      +ve      |
#   mul.Mat52.variance       |  0.19197042264117684  |      +ve      |
#   mul.Mat52.lengthscale    |   0.4549780685253769  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 86.37544042527614
#
# Name : GP regression
# Objective : 27.591908650039304
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.RatQuad.variance     |  0.5731011992472655  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999269239211042  |      +ve      |
#   mul.RatQuad.power        |   2.000072667614865  |      +ve      |
#   mul.Mat52.variance       |  0.5731011992472655  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9998828775062771  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# -6.659846907758681
#
# Name : GP regression
# Objective : -15.459999113678384
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    4.328680186171679  |               |
#   mul.RatQuad.variance          |  0.26528060785582047  |      +ve      |
#   mul.RatQuad.lengthscale       |   4.6270334067955705  |      +ve      |
#   mul.RatQuad.power             |  0.02302092055176204  |      +ve      |
#   mul.std_periodic.variance     |  0.26528060785582047  |      +ve      |
#   mul.std_periodic.period       |   0.8393143692963494  |      +ve      |
#   mul.std_periodic.lengthscale  |    1.750004313025114  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 89.90157344782554
#
# Name : GP regression
# Objective : 27.622107209914134
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.RatQuad.variance          |  0.5736395950179066  |      +ve      |
#   mul.RatQuad.lengthscale       |  0.9983985176297198  |      +ve      |
#   mul.RatQuad.power             |  2.0014927876419217  |      +ve      |
#   mul.std_periodic.variance     |  0.5736395950179066  |      +ve      |
#   mul.std_periodic.period       |  0.9988123273266295  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.999424227426408  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 5.981654475818559
#
# Name : GP regression
# Objective : -7.4063804704899
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |   4.2610382547097965  |               |
#   mul.RatQuad.variance         |  0.19197221235178746  |      +ve      |
#   mul.RatQuad.lengthscale      |   0.9999891491767406  |      +ve      |
#   mul.RatQuad.power            |    2.000008986046825  |      +ve      |
#   mul.Exponential.variance     |  0.19197221235178746  |      +ve      |
#   mul.Exponential.lengthscale  |   0.9999921646118176  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 86.37806379402687
#
# Name : GP regression
# Objective : 27.59322033441467
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.RatQuad.variance         |   0.573124639271828  |      +ve      |
#   mul.RatQuad.lengthscale      |  0.9998603346522783  |      +ve      |
#   mul.RatQuad.power            |   2.000138256811493  |      +ve      |
#   mul.Exponential.variance     |   0.573124639271828  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9998700222145663  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 2.515294924892679
#
# Name : GP regression
# Objective : -7.406692294552977
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   constmap.C               |   4.261026586516468  |               |
#   mul.Mat32.variance       |  0.1919709917006466  |      +ve      |
#   mul.Mat32.lengthscale    |  0.8150634843577728  |      +ve      |
#   mul.rbf.variance         |  0.1919709917006466  |      +ve      |
#   mul.rbf.lengthscale      |  0.6349366167684759  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 82.90783641168493
#
# Name : GP regression
# Objective : 27.59097459464356
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  0.5730843731036059  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9999654014801683  |      +ve      |
#   mul.rbf.variance         |  0.5730843731036059  |      +ve      |
#   mul.rbf.lengthscale      |   0.999926365361681  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.981030810734659
#
# Name : GP regression
# Objective : -7.40669230303185
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261025547615312  |               |
#   mul.Mat32.variance       |  0.19197017769458047  |      +ve      |
#   mul.Mat32.lengthscale    |   0.4308446462189005  |      +ve      |
#   mul.RatQuad.variance     |  0.19197017769458047  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.5364459292927136  |      +ve      |
#   mul.RatQuad.power        |     2.56180445055314  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 86.37620877457589
#
# Name : GP regression
# Objective : 27.592292824689174
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  0.5731108477579707  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9998735163007407  |      +ve      |
#   mul.RatQuad.variance     |  0.5731108477579707  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999073632836738  |      +ve      |
#   mul.RatQuad.power        |    2.00009203278765  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 2.5152949388854147
#
# Name : GP regression
# Objective : -7.406692287556609
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261023650846186  |               |
#   mul.Mat32.variance       |  0.19197038214074844  |      +ve      |
#   mul.Mat32.lengthscale    |   0.5054717422328874  |      +ve      |
#   mul.Mat32_1.variance     |  0.19197038214074844  |      +ve      |
#   mul.Mat32_1.lengthscale  |   0.5054717422328874  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 82.91047289211109
#
# Name : GP regression
# Objective : 27.59229283485664
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  0.5731069178304798  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9998730864927805  |      +ve      |
#   mul.Mat32_1.variance     |  0.5731069178304798  |      +ve      |
#   mul.Mat32_1.lengthscale  |  0.9998730864927805  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 2.5152949071140007
#
# Name : GP regression
# Objective : -7.406692303442316
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   constmap.C               |   4.261026355377011  |               |
#   mul.Mat32.variance       |  0.1919712655343588  |      +ve      |
#   mul.Mat32.lengthscale    |  0.5483953935659371  |      +ve      |
#   mul.Mat52.variance       |  0.1919712655343588  |      +ve      |
#   mul.Mat52.lengthscale    |  0.4890831245726928  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 82.9096999526777
#
# Name : GP regression
# Objective : 27.591906365139945
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  0.5731011350689522  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9999000674186204  |      +ve      |
#   mul.Mat52.variance       |  0.5731011350689522  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9998828593596334  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.981030844088636
#
# Name : GP regression
# Objective : -7.406692286354861
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    4.261025647751458  |               |
#   mul.Mat32.variance            |  0.19197099451656113  |      +ve      |
#   mul.Mat32.lengthscale         |   0.3290182827761175  |      +ve      |
#   mul.std_periodic.variance     |  0.19197099451656113  |      +ve      |
#   mul.std_periodic.period       |   1.1866388972766584  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5890347613024083  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.4428983290812
#
# Name : GP regression
# Objective : 27.625637601941833
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.Mat32.variance            |  0.5737001087704517  |      +ve      |
#   mul.Mat32.lengthscale         |  0.9975869752368451  |      +ve      |
#   mul.std_periodic.variance     |  0.5737001087704517  |      +ve      |
#   mul.std_periodic.period       |  0.9988357699920558  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9994067148820616  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 2.5152952073311603
#
# Name : GP regression
# Objective : -7.406692153333736
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |     4.26102337522441  |               |
#   mul.Mat32.variance           |  0.19197007685375095  |      +ve      |
#   mul.Mat32.lengthscale        |  0.45795403814724434  |      +ve      |
#   mul.Exponential.variance     |  0.19197007685375095  |      +ve      |
#   mul.Exponential.lengthscale  |   0.5956838214844942  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 82.91236613490243
#
# Name : GP regression
# Objective : 27.59323945625231
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Mat32.variance           |  0.5731249616910279  |      +ve      |
#   mul.Mat32.lengthscale        |  0.9998075372610491  |      +ve      |
#   mul.Exponential.variance     |  0.5731249616910279  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9998681770813196  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 2.5154000569184696
#
# Name : GP regression
# Objective : -7.406639728540082
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   constmap.C               |   4.261025894949556  |               |
#   mul.Mat52.variance       |  0.1919714873927047  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9999681740614531  |      +ve      |
#   mul.rbf.variance         |  0.1919714873927047  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999422219155275  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 82.90762530530779
#
# Name : GP regression
# Objective : 27.590869041454987
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat52.variance       |  0.5730836094460202  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9999681061982455  |      +ve      |
#   mul.rbf.variance         |  0.5730836094460202  |      +ve      |
#   mul.rbf.lengthscale      |  0.9999420955852596  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.981030817960026
#
# Name : GP regression
# Objective : -7.406692299419166
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |      4.2610250087645  |               |
#   mul.Mat52.variance       |  0.19197024423142886  |      +ve      |
#   mul.Mat52.lengthscale    |  0.45914205753542736  |      +ve      |
#   mul.RatQuad.variance     |  0.19197024423142886  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.6211443613391963  |      +ve      |
#   mul.RatQuad.power        |    2.441420675738704  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 86.37544121684658
#
# Name : GP regression
# Objective : 27.591909045824522
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat52.variance       |  0.5731006395487381  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9998829172381472  |      +ve      |
#   mul.RatQuad.variance     |  0.5731006395487381  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.9999269486457196  |      +ve      |
#   mul.RatQuad.power        |  2.0000726429438647  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 2.5152949066336525
#
# Name : GP regression
# Objective : -7.40669230368249
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261026125772715  |               |
#   mul.Mat52.variance       |   0.1919714662668868  |      +ve      |
#   mul.Mat52.lengthscale    |  0.48791746490502036  |      +ve      |
#   mul.Mat32.variance       |   0.1919714662668868  |      +ve      |
#   mul.Mat32.lengthscale    |   0.5473077863091562  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 82.90970010531332
#
# Name : GP regression
# Objective : 27.591906441457756
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat52.variance       |  0.5731012249519641  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9998828672206603  |      +ve      |
#   mul.Mat32.variance       |  0.5731012249519641  |      +ve      |
#   mul.Mat32.lengthscale    |  0.9999000741312443  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 2.5152949029717426
#
# Name : GP regression
# Objective : -7.406692305513445
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    4.261025938681816  |               |
#   mul.Mat52.variance       |  0.19197117649335704  |      +ve      |
#   mul.Mat52.lengthscale    |   0.5346881896814757  |      +ve      |
#   mul.Mat52_1.variance     |  0.19197117649335704  |      +ve      |
#   mul.Mat52_1.lengthscale  |   0.5346881896814757  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 82.90909113030465
#
# Name : GP regression
# Objective : 27.591601953953415
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat52.variance       |  0.5730958621968493  |      +ve      |
#   mul.Mat52.lengthscale    |  0.9999078168669371  |      +ve      |
#   mul.Mat52_1.variance     |  0.5730958621968493  |      +ve      |
#   mul.Mat52_1.lengthscale  |  0.9999078168669371  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 5.981030859716498
#
# Name : GP regression
# Objective : -7.40669227854093
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    4.261026593924925  |               |
#   mul.Mat52.variance            |   0.1919707108455703  |      +ve      |
#   mul.Mat52.lengthscale         |  0.34781894185028644  |      +ve      |
#   mul.std_periodic.variance     |  0.19197071084557094  |      +ve      |
#   mul.std_periodic.period       |   0.4720937500067208  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.7227094131536944  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.4287870767067
#
# Name : GP regression
# Objective : 27.61858197575458
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.Mat52.variance            |  0.5735746880158552  |      +ve      |
#   mul.Mat52.lengthscale         |   0.997707727508978  |      +ve      |
#   mul.std_periodic.variance     |  0.5735746880158552  |      +ve      |
#   mul.std_periodic.period       |  0.9990892128993296  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9995319799359443  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 2.5152949927154715
#
# Name : GP regression
# Objective : -7.406692260641581
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |    4.261028984166291  |               |
#   mul.Mat52.variance           |  0.19196971025025186  |      +ve      |
#   mul.Mat52.lengthscale        |   0.4538440691039478  |      +ve      |
#   mul.Exponential.variance     |  0.19196971025025186  |      +ve      |
#   mul.Exponential.lengthscale  |   0.6435205446743221  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 82.91119423879442
#
# Name : GP regression
# Objective : 27.592653508198307
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Mat52.variance           |  0.5731145213176148  |      +ve      |
#   mul.Mat52.lengthscale        |  0.9998219635586816  |      +ve      |
#   mul.Exponential.variance     |  0.5731145213176148  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9998959816170243  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 5.981031130058078
#
# Name : GP regression
# Objective : -7.40669214337014
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    4.261031027597013  |               |
#   mul.std_periodic.variance     |  0.19196870024871598  |      +ve      |
#   mul.std_periodic.period       |   0.9040539552009216  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.9501200164160645  |      +ve      |
#   mul.rbf.variance              |  0.19196870024870372  |      +ve      |
#   mul.rbf.lengthscale           |   0.6007636427892094  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.39236964965042
#
# Name : GP regression
# Objective : 27.600373262226437
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  0.5732506722682528  |      +ve      |
#   mul.std_periodic.period       |  0.9996882954664147  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9998380632780792  |      +ve      |
#   mul.rbf.variance              |  0.5732506722682528  |      +ve      |
#   mul.rbf.lengthscale           |   0.998504954924891  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# -11.858739288562141
#
# Name : GP regression
# Objective : -18.059445304080114
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                |                  value  |  constraints  |  priors
#   constmap.C                    |      4.253468020074626  |               |
#   mul.std_periodic.variance     |    0.16138992896573467  |      +ve      |
#   mul.std_periodic.period       |     1.5608921119406143  |      +ve      |
#   mul.std_periodic.lengthscale  |    0.40921271615110133  |      +ve      |
#   mul.RatQuad.variance          |    0.16138992896573467  |      +ve      |
#   mul.RatQuad.lengthscale       |       6.99826349129023  |      +ve      |
#   mul.RatQuad.power             |  0.0012575706820673635  |      +ve      |
#   Gaussian_noise.variance       |                  1e-06  |   +ve fixed   |
# 89.90156070519274
#
# Name : GP regression
# Objective : 27.62210083859774
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  0.5736395205662422  |      +ve      |
#   mul.std_periodic.period       |  0.9988128985612288  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9994245365935239  |      +ve      |
#   mul.RatQuad.variance          |  0.5736395205662422  |      +ve      |
#   mul.RatQuad.lengthscale       |  0.9983995791184375  |      +ve      |
#   mul.RatQuad.power             |  2.0014916918505334  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 5.981030803384456
#
# Name : GP regression
# Objective : -7.406692306706951
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |     4.26102654932881  |               |
#   mul.std_periodic.variance     |  0.19197089312768945  |      +ve      |
#   mul.std_periodic.period       |   0.8942150868974508  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5152528377333079  |      +ve      |
#   mul.Mat32.variance            |  0.19197089312786364  |      +ve      |
#   mul.Mat32.lengthscale         |   0.3182378372897274  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.44287651011936
#
# Name : GP regression
# Objective : 27.625626692460912
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  0.5737005317471999  |      +ve      |
#   mul.std_periodic.period       |  0.9988371690398872  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9994074493619729  |      +ve      |
#   mul.Mat32.variance            |  0.5737005317471999  |      +ve      |
#   mul.Mat32.lengthscale         |  0.9975903059428732  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 5.981030851271612
#
# Name : GP regression
# Objective : -7.406692282763373
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    4.261026139565486  |               |
#   mul.std_periodic.variance     |  0.19197120637075318  |      +ve      |
#   mul.std_periodic.period       |   0.4693618844155887  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.7210945085175439  |      +ve      |
#   mul.Mat52.variance            |  0.19197120637075243  |      +ve      |
#   mul.Mat52.lengthscale         |  0.34524682673709356  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.42877142434497
#
# Name : GP regression
# Objective : 27.618574149573714
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  0.5735744933725052  |      +ve      |
#   mul.std_periodic.period       |  0.9990906958951533  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9995327636532718  |      +ve      |
#   mul.Mat52.variance            |  0.5735744933725052  |      +ve      |
#   mul.Mat52.lengthscale         |  0.9977117932566116  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 3.6055861322700693
#
# Name : GP regression
# Objective : -10.327282593664009
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                  |               value  |  constraints  |  priors
#   constmap.C                      |   4.519365507726545  |               |
#   mul.std_periodic.variance       |  0.3002666331914508  |      +ve      |
#   mul.std_periodic.period         |  0.8580844426566479  |      +ve      |
#   mul.std_periodic.lengthscale    |  1.1425563036017552  |      +ve      |
#   mul.std_periodic_1.variance     |  0.3002666331914508  |      +ve      |
#   mul.std_periodic_1.period       |  0.8580844426566479  |      +ve      |
#   mul.std_periodic_1.lengthscale  |  1.1425563036017552  |      +ve      |
#   Gaussian_noise.variance         |               1e-06  |   +ve fixed   |
# 83.31277885947898
#
# Name : GP regression
# Objective : 24.32770991574086
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.                  |               value  |  constraints  |  priors
#   linmap.A                        |              (4, 1)  |               |
#   mul.std_periodic.variance       |  1.0850252232059534  |      +ve      |
#   mul.std_periodic.period         |  0.9998166980722862  |      +ve      |
#   mul.std_periodic.lengthscale    |  0.8020673725726983  |      +ve      |
#   mul.std_periodic_1.variance     |  1.0850252232059534  |      +ve      |
#   mul.std_periodic_1.period       |  0.9998166980722862  |      +ve      |
#   mul.std_periodic_1.lengthscale  |  0.8020673725726983  |      +ve      |
#   Gaussian_noise.variance         |               1e-06  |   +ve fixed   |
# -20.49310447441573
#
# Name : GP regression
# Objective : -20.643759945607044
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    4.320966377397636  |               |
#   mul.std_periodic.variance     |   0.2814924211270777  |      +ve      |
#   mul.std_periodic.period       |   1.0091867840785071  |      +ve      |
#   mul.std_periodic.lengthscale  |   1.6189144028148053  |      +ve      |
#   mul.Exponential.variance      |  0.28149242121451484  |      +ve      |
#   mul.Exponential.lengthscale   |    9456.245682240697  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.47286868302052
#
# Name : GP regression
# Objective : 27.640622778911496
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  0.5739645220692582  |      +ve      |
#   mul.std_periodic.period       |  0.9981901085954894  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9991061890855786  |      +ve      |
#   mul.Exponential.variance      |  0.5739645220692582  |      +ve      |
#   mul.Exponential.lengthscale   |  0.9977550229033434  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 2.5152950747909806
#
# Name : GP regression
# Objective : -7.406692219603826
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |     4.26102643206445  |               |
#   mul.Exponential.variance     |  0.19197091987132903  |      +ve      |
#   mul.Exponential.lengthscale  |   0.8772863462367452  |      +ve      |
#   mul.rbf.variance             |  0.19197091987132903  |      +ve      |
#   mul.rbf.lengthscale          |   0.6512520374370341  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 82.90835260723011
#
# Name : GP regression
# Objective : 27.59123269241615
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.5730894249908889  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999638412161929  |      +ve      |
#   mul.rbf.variance             |  0.5730894249908889  |      +ve      |
#   mul.rbf.lengthscale          |  0.9998875864248895  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 5.981030805548386
#
# Name : GP regression
# Objective : -7.406692305624986
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |    4.261027017153256  |               |
#   mul.Exponential.variance     |  0.19197104781336843  |      +ve      |
#   mul.Exponential.lengthscale  |  0.43326709523405965  |      +ve      |
#   mul.RatQuad.variance         |  0.19197104781336843  |      +ve      |
#   mul.RatQuad.lengthscale      |   0.3609369782508663  |      +ve      |
#   mul.RatQuad.power            |    2.838172449866344  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 86.37805963653696
#
# Name : GP regression
# Objective : 27.59321825566971
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.5731237369619264  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9998698534024134  |      +ve      |
#   mul.RatQuad.variance         |  0.5731237369619264  |      +ve      |
#   mul.RatQuad.lengthscale      |  0.9998601535337843  |      +ve      |
#   mul.RatQuad.power            |  2.0001384343267916  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 2.515294914937755
#
# Name : GP regression
# Objective : -7.406692299530439
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |    4.261027780946903  |               |
#   mul.Exponential.variance     |  0.19197156693712403  |      +ve      |
#   mul.Exponential.lengthscale  |   0.5356063372027183  |      +ve      |
#   mul.Mat32.variance           |  0.19197156693712403  |      +ve      |
#   mul.Mat32.lengthscale        |  0.38834758794449353  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 82.91236176553926
#
# Name : GP regression
# Objective : 27.593237271570725
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.5731267336659013  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9998680320014257  |      +ve      |
#   mul.Mat32.variance           |  0.5731267336659013  |      +ve      |
#   mul.Mat32.lengthscale        |  0.9998073232299167  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 2.515294932303526
#
# Name : GP regression
# Objective : -7.406692290847554
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |    4.261027203868589  |               |
#   mul.Exponential.variance     |  0.19197135513525798  |      +ve      |
#   mul.Exponential.lengthscale  |   0.6269533247698065  |      +ve      |
#   mul.Mat52.variance           |  0.19197135513525798  |      +ve      |
#   mul.Mat52.lengthscale        |   0.4323656860302033  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 82.91119141339576
#
# Name : GP regression
# Objective : 27.592652095498973
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.5731161199950316  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9998959013925637  |      +ve      |
#   mul.Mat52.variance           |  0.5731161199950316  |      +ve      |
#   mul.Mat52.lengthscale        |  0.9998218220611577  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# -17.47940581268466
#
# Name : GP regression
# Objective : -19.13691061474151
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   4.2832625739869945  |               |
#   mul.Exponential.variance      |   0.1914036854332049  |      +ve      |
#   mul.Exponential.lengthscale   |   13806.829477003688  |      +ve      |
#   mul.std_periodic.variance     |  0.19140368533923446  |      +ve      |
#   mul.std_periodic.period       |   1.1033217773558444  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.8271662728243881  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 86.4726823942346
#
# Name : GP regression
# Objective : 27.640529634518533
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.Exponential.variance      |  0.5739646766323736  |      +ve      |
#   mul.Exponential.lengthscale   |  0.9977655807648083  |      +ve      |
#   mul.std_periodic.variance     |  0.5739646766323736  |      +ve      |
#   mul.std_periodic.period       |  0.9981965206872222  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9991095762520565  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 2.5162822805347282
#
# Name : GP regression
# Objective : -7.4061986167319525
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.                 |                value  |  constraints  |  priors
#   constmap.C                     |    4.261042831443297  |               |
#   mul.Exponential.variance       |  0.19197330700603024  |      +ve      |
#   mul.Exponential.lengthscale    |   0.9999622426513982  |      +ve      |
#   mul.Exponential_1.variance     |  0.19197330700603024  |      +ve      |
#   mul.Exponential_1.lengthscale  |   0.9999622426513982  |      +ve      |
#   Gaussian_noise.variance        |                1e-06  |   +ve fixed   |
# 82.91520517141247
#
# Name : GP regression
# Objective : 27.594658974507325
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.                 |               value  |  constraints  |  priors
#   linmap.A                       |              (4, 1)  |               |
#   mul.Exponential.variance       |  0.5731503550998823  |      +ve      |
#   mul.Exponential.lengthscale    |  0.9998015667353177  |      +ve      |
#   mul.Exponential_1.variance     |  0.5731503550998823  |      +ve      |
#   mul.Exponential_1.lengthscale  |  0.9998015667353177  |      +ve      |
#   Gaussian_noise.variance        |               1e-06  |   +ve fixed   |
# -20.49310447441573 (<GPy.kern.src.prod.Prod object at 0x7f29cbfe4890>, <GPy.models.gp_regression.GPRegression object at 0x7f29cbf7b0d0>)

# %%
def best_kernel_search(X, y):
    
    kernel = GPy.kern.StdPeriodic(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0) * GPy.kern.RatQuad(input_dim=X.shape[1], variance=1.0, lengthscale=1.0)
    mean = GPy.mappings.Constant(input_dim = X.shape[1], output_dim = 1, value = np.mean(y))
    model = GPy.models.GPRegression(X, y, kernel, noise_var=0.001**2, mean_function=mean)
    model.Gaussian_noise.variance.fix()
    model.optimize_restarts(100, verbose=False)

    n = model.num_data
    k = len(model.optimizer_array)
    log_likelihood = model.log_likelihood()
    
    bic = k * np.log(n) - 2 * log_likelihood
    print(bic)
    print(model)

    return model

# %%
store = best_kernel_search(X, y)
# Out:
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:130: RuntimeWarning:overflow encountered in divide
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:131: RuntimeWarning:invalid value encountered in sin
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:131: RuntimeWarning:overflow encountered in square
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/stationary.py:168: RuntimeWarning:overflow encountered in divide
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:509: RuntimeWarning:overflow encountered in square
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:511: RuntimeWarning:divide by zero encountered in divide
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:511: RuntimeWarning:invalid value encountered in multiply
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:513: RuntimeWarning:divide by zero encountered in divide
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:513: RuntimeWarning:invalid value encountered in divide
#  /home/pupper/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:49: RuntimeWarning:invalid value encountered in reduce
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:521: RuntimeWarning:invalid value encountered in multiply
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/standard_periodic.py:526: RuntimeWarning:invalid value encountered in multiply
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/stationary.py:781: RuntimeWarning:invalid value encountered in multiply
#  /home/pupper/anaconda3/lib/python3.11/site-packages/GPy/kern/src/stationary.py:788: RuntimeWarning:invalid value encountered in multiply
# -19.286127195084624
#
# Name : GP regression
# Objective : -21.773139257341356
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                |                 value  |  constraints  |  priors
#   constmap.C                    |     4.287000806090743  |               |
#   mul.std_periodic.variance     |    0.3110275017585567  |      +ve      |
#   mul.std_periodic.period       |    0.8799407202343502  |      +ve      |
#   mul.std_periodic.lengthscale  |     1.181736676646456  |      +ve      |
#   mul.RatQuad.variance          |     0.182798179837257  |      +ve      |
#   mul.RatQuad.lengthscale       |    2.0587998795711075  |      +ve      |
#   mul.RatQuad.power             |  0.003581960169483112  |      +ve      |
#   Gaussian_noise.variance       |                 1e-06  |   +ve fixed   |
