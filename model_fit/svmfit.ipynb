# %%
import numpy as np
import math
import GPy
import matplotlib.pyplot as plt
import seaborn

# %%
def generate_data():
    data = np.loadtxt('./../svm.csv', delimiter=",")
    sample = np.random.choice(data.shape[0], size = 32, replace=False)
    samp_data = data[sample]
    #X = samp_data[:, :-1]
    #y = samp_data[:, -1].reshape(-1, 1)
    X = samp_data[:, :-1]
    y = samp_data[:, -1].reshape(-1, 1)
    return X, y

X, y = generate_data()
y = np.log10(y)

# %%
def base_kernel_search(X, y):
    kernel_comp = [GPy.kern.RBF(input_dim=X.shape[1], variance=1.0, lengthscale=1.0, useGPU=True), 
                         GPy.kern.RatQuad(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern32(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern52(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.StdPeriodic(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0, useGPU = True),
                         GPy.kern.Exponential(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0)]
    
    best_model = None
    best_bic = float('inf')
    mean = GPy.mappings.Constant(input_dim = X.shape[1], output_dim = 1, value = np.mean(y))


    for kernel1 in kernel_comp:
        kernel = kernel1
        model = GPy.models.GPRegression(X, y, kernel, noise_var=0.001**2, mean_function=mean)
        model.Gaussian_noise.variance.fix()
        model.optimize_restarts(5, verbose=False)
        n = model.num_data
        k = len(model.parameters)
        log_likelihood = model.log_likelihood()
        
        bic = k * np.log(n) - 2 * log_likelihood
        print(bic)
        print(model)

        if bic < best_bic:
            best_model = (kernel, model)
            best_bic = bic

    print(best_bic, best_model)

# %%
import warnings
with warnings.catch_warnings(action="ignore"):
    base_kernel_search(X, y)
# Out:
# 49.90085590602205
#
# Name : GP regression
# Objective : 19.751824098811436
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354464174126083  |               |
#   rbf.variance             |   0.20121269712247727  |      +ve      |
#   rbf.lengthscale          |  0.018559564081515947  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 49.90085592765645
#
# Name : GP regression
# Objective : 19.751824109628636
# Number of Parameters : 5
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354453791521125  |               |
#   RatQuad.variance         |   0.20121190595776378  |      +ve      |
#   RatQuad.lengthscale      |  0.002412189227573945  |      +ve      |
#   RatQuad.power            |     2.549206896163973  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 49.90085590468486
#
# Name : GP regression
# Objective : 19.75182409814284
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354501612928884  |               |
#   Mat32.variance           |   0.20121123992444193  |      +ve      |
#   Mat32.lengthscale        |  0.008862721916886388  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 49.90085589540002
#
# Name : GP regression
# Objective : 19.75182409350042
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |   2.5354470951850407  |               |
#   Mat52.variance           |   0.2012124881332304  |      +ve      |
#   Mat52.lengthscale        |  0.01027970754609826  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 95.32480495625614
#
# Name : GP regression
# Objective : 42.46379862392848
# Number of Parameters : 5
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   GP_regression.            |                value  |  constraints  |  priors
#   constmap.C                |   0.8375076492353721  |               |
#   std_periodic.variance     |   0.7618354265784593  |      +ve      |
#   std_periodic.period       |  0.24901582829108124  |      +ve      |
#   std_periodic.lengthscale  |   0.6069007969563067  |      +ve      |
#   Gaussian_noise.variance   |                1e-06  |   +ve fixed   |
# 49.90085591100345
#
# Name : GP regression
# Objective : 19.751824101302134
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                  value  |  constraints  |  priors
#   constmap.C               |     2.5354450495334016  |               |
#   Exponential.variance     |    0.20121357634848977  |      +ve      |
#   Exponential.lengthscale  |  0.0060391015483134275  |      +ve      |
#   Gaussian_noise.variance  |                  1e-06  |   +ve fixed   |
# 49.90085589540002 (<GPy.kern.src.stationary.Matern52 object at 0x735dd3e7cbd0>, <GPy.models.gp_regression.GPRegression object at 0x735dd3ec06d0>)

# %%
def kernel_search(X, y):
    kernel_comp = [GPy.kern.RBF(input_dim=X.shape[1], variance=1.0, lengthscale=1.0), 
                         GPy.kern.RatQuad(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern32(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Matern52(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.StdPeriodic(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0),
                         GPy.kern.Exponential(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0)]
    
    best_model = None
    best_bic = float('inf')
    mean_comp = [GPy.mappings.Constant(input_dim = X.shape[1], output_dim = 1, value = np.mean(y)), 
            GPy.mappings.Linear(input_dim = X.shape[1], output_dim = 1)]


    for kernel1 in kernel_comp:
        for kernel2 in kernel_comp:
            for mean in mean_comp:
                # Combine kernels
                kernel = kernel1 * kernel2
                model = GPy.models.GPRegression(X, y, kernel, noise_var=0.001**2, mean_function=mean)
                model.Gaussian_noise.variance.fix()
                model.optimize()
                n = model.num_data
                k = len(model.optimizer_array)
                log_likelihood = model.log_likelihood()
                
                bic = k * np.log(n) - 2 * log_likelihood
                print(bic)
                print(model)

                if bic < best_bic:
                    best_model = (kernel, model)
                    best_bic = bic

    print(best_bic, best_model)

# %%
import warnings
with warnings.catch_warnings(action="ignore"):
    kernel_search(X, y)
# Out:
# 56.832327861771034
#
# Name : GP regression
# Objective : 19.751824173886202
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354469452734847  |               |
#   mul.rbf.variance         |     0.448567329787389  |      +ve      |
#   mul.rbf.lengthscale      |  0.027027514339263196  |      +ve      |
#   mul.rbf_1.variance       |     0.448567329787389  |      +ve      |
#   mul.rbf_1.lengthscale    |  0.027027514339263196  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 681.6767327569249
#
# Name : GP regression
# Objective : 326.9754227672636
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |  1.2169865871437486  |      +ve      |
#   mul.rbf.lengthscale      |  1.0511699858425347  |      +ve      |
#   mul.rbf_1.variance       |  1.2169865871437486  |      +ve      |
#   mul.rbf_1.lengthscale    |  1.0511699858425347  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 60.29806394482064
#
# Name : GP regression
# Objective : 19.75182426401114
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |     2.535429459679842  |               |
#   mul.rbf.variance         |   0.44856508992676447  |      +ve      |
#   mul.rbf.lengthscale      |    0.7254118915477049  |      +ve      |
#   mul.RatQuad.variance     |    0.4485650899267305  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.007337215091968427  |      +ve      |
#   mul.RatQuad.power        |     3.415583620590247  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 140.87830633670922
#
# Name : GP regression
# Objective : 54.84334160575583
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |   2.070245405605375  |      +ve      |
#   mul.rbf.lengthscale      |   0.778799565874685  |      +ve      |
#   mul.RatQuad.variance     |   2.070245405605375  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.4449187425188305  |      +ve      |
#   mul.RatQuad.power        |   2.283747781735869  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 56.832327707211135
#
# Name : GP regression
# Objective : 19.75182409660625
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    2.535447928456921  |               |
#   mul.rbf.variance         |  0.44856720136964034  |      +ve      |
#   mul.rbf.lengthscale      |   0.5767804844184552  |      +ve      |
#   mul.Mat32.variance       |   0.4485672013696377  |      +ve      |
#   mul.Mat32.lengthscale    |  0.00886108888776316  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 125.73294019103514
#
# Name : GP regression
# Objective : 49.00352648431866
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |  1.3605646338636492  |      +ve      |
#   mul.rbf.lengthscale      |  0.8995089595001506  |      +ve      |
#   mul.Mat32.variance       |  1.3605646338636492  |      +ve      |
#   mul.Mat32.lengthscale    |  0.6260936063191391  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 56.83232775043945
#
# Name : GP regression
# Objective : 19.751824118220405
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |     2.535449468017693  |               |
#   mul.rbf.variance         |   0.44856754822691197  |      +ve      |
#   mul.rbf.lengthscale      |     0.549260347608305  |      +ve      |
#   mul.Mat52.variance       |    0.4485675482268875  |      +ve      |
#   mul.Mat52.lengthscale    |  0.010678172863410973  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 123.25084029206106
#
# Name : GP regression
# Objective : 47.76247653483162
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.rbf.variance         |   1.411437453732633  |      +ve      |
#   mul.rbf.lengthscale      |  0.7298053720385642  |      +ve      |
#   mul.Mat52.variance       |   1.411437453732633  |      +ve      |
#   mul.Mat52.lengthscale    |  0.3993152004341497  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 38.69869404551018
#
# Name : GP regression
# Objective : 8.952139314355911
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   2.5298479837559777  |               |
#   mul.rbf.variance              |  0.48428451039624165  |      +ve      |
#   mul.rbf.lengthscale           |     3098.21431655588  |      +ve      |
#   mul.std_periodic.variance     |   0.4842845103968675  |      +ve      |
#   mul.std_periodic.period       |   0.6923217993476523  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5300800675348392  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 122.01512033977531
#
# Name : GP regression
# Objective : 45.411748607288885
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.rbf.variance              |   1.212126771236845  |      +ve      |
#   mul.rbf.lengthscale           |  0.9836629227489151  |      +ve      |
#   mul.std_periodic.variance     |   1.212126771236845  |      +ve      |
#   mul.std_periodic.period       |  0.8389084383826696  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.7959170749433091  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 56.83232773726256
#
# Name : GP regression
# Objective : 19.75182411163196
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |    2.5354498056687564  |               |
#   mul.rbf.variance             |    0.4485689723399918  |      +ve      |
#   mul.rbf.lengthscale          |    0.6370160447044156  |      +ve      |
#   mul.Exponential.variance     |    0.4485689723399909  |      +ve      |
#   mul.Exponential.lengthscale  |  0.006150849169724252  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 117.08234938407077
#
# Name : GP regression
# Objective : 44.678231080836476
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.rbf.variance             |  1.0449863337165095  |      +ve      |
#   mul.rbf.lengthscale          |  1.0062572789400563  |      +ve      |
#   mul.Exponential.variance     |  1.0449863337165095  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9956715534672484  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 60.298064020128734
#
# Name : GP regression
# Objective : 19.751824301665188
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354472004307014  |               |
#   mul.RatQuad.variance     |   0.44856714043956203  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.007637847548265565  |      +ve      |
#   mul.RatQuad.power        |     3.403808637863702  |      +ve      |
#   mul.rbf.variance         |    0.4485671404396184  |      +ve      |
#   mul.rbf.lengthscale      |     0.722453559383541  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 124.64594468748163
#
# Name : GP regression
# Objective : 46.72716078114205
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   linmap.A                 |               (4, 1)  |               |
#   mul.RatQuad.variance     |   1.3347381543810648  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.42821589665054977  |      +ve      |
#   mul.RatQuad.power        |    2.308191626344045  |      +ve      |
#   mul.rbf.variance         |   1.3347381543810648  |      +ve      |
#   mul.rbf.lengthscale      |   0.7466421279125318  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 63.763800905865764
#
# Name : GP regression
# Objective : 19.75182479313384
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.             |                 value  |  constraints  |  priors
#   constmap.C                 |    2.5354472186194172  |               |
#   mul.RatQuad.variance       |    0.4485673977666901  |      +ve      |
#   mul.RatQuad.lengthscale    |  0.023558709551913554  |      +ve      |
#   mul.RatQuad.power          |     2.982384735339969  |      +ve      |
#   mul.RatQuad_1.variance     |    0.4485673977666901  |      +ve      |
#   mul.RatQuad_1.lengthscale  |  0.023558709551913554  |      +ve      |
#   mul.RatQuad_1.power        |     2.982384735339969  |      +ve      |
#   Gaussian_noise.variance    |                 1e-06  |   +ve fixed   |
# 128.3779769040664
#
# Name : GP regression
# Objective : 46.860308938034564
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.             |               value  |  constraints  |  priors
#   linmap.A                   |              (4, 1)  |               |
#   mul.RatQuad.variance       |  1.3680132892165886  |      +ve      |
#   mul.RatQuad.lengthscale    |  0.5814553895087473  |      +ve      |
#   mul.RatQuad.power          |  2.2145510175638745  |      +ve      |
#   mul.RatQuad_1.variance     |  1.3680132892165886  |      +ve      |
#   mul.RatQuad_1.lengthscale  |  0.5814553895087473  |      +ve      |
#   mul.RatQuad_1.power        |  2.2145510175638745  |      +ve      |
#   Gaussian_noise.variance    |               1e-06  |   +ve fixed   |
# 60.298063670042595
#
# Name : GP regression
# Objective : 19.751824126622118
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354405823877606  |               |
#   mul.RatQuad.variance     |    0.4485727081766966  |      +ve      |
#   mul.RatQuad.lengthscale  |     0.110341590092598  |      +ve      |
#   mul.RatQuad.power        |    2.7417520449567503  |      +ve      |
#   mul.Mat32.variance       |    0.4485727081766947  |      +ve      |
#   mul.Mat32.lengthscale    |  0.009693301447531916  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 123.79965461548586
#
# Name : GP regression
# Objective : 46.30401574514416
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.RatQuad.variance     |  1.3870929860726802  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.758142872988761  |      +ve      |
#   mul.RatQuad.power        |  2.1185282716015688  |      +ve      |
#   mul.Mat32.variance       |  1.3870929860726802  |      +ve      |
#   mul.Mat32.lengthscale    |  0.5969650359121992  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 60.29806391874152
#
# Name : GP regression
# Objective : 19.75182425097158
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354427498345755  |               |
#   mul.RatQuad.variance     |   0.44857299148041585  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.008451351554994772  |      +ve      |
#   mul.RatQuad.power        |    3.3418949867985135  |      +ve      |
#   mul.Mat52.variance       |    0.4485729914804061  |      +ve      |
#   mul.Mat52.lengthscale    |   0.07266588754534616  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 124.16659645235757
#
# Name : GP regression
# Objective : 46.487486663580015
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.RatQuad.variance     |  1.3899768590366792  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.5575565364362405  |      +ve      |
#   mul.RatQuad.power        |  2.2291313496370284  |      +ve      |
#   mul.Mat52.variance       |  1.3899768590366792  |      +ve      |
#   mul.Mat52.lengthscale    |   0.576063948330109  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 52.194807591344926
#
# Name : GP regression
# Objective : 13.96732813587342
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                |                 value  |  constraints  |  priors
#   constmap.C                    |     2.482045939664537  |               |
#   mul.RatQuad.variance          |    0.4486396239877355  |      +ve      |
#   mul.RatQuad.lengthscale       |    15.431652930598892  |      +ve      |
#   mul.RatQuad.power             |  0.009048026712815004  |      +ve      |
#   mul.std_periodic.variance     |     0.448639623987703  |      +ve      |
#   mul.std_periodic.period       |    0.6969158689898862  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.27100915596902053  |      +ve      |
#   Gaussian_noise.variance       |                 1e-06  |   +ve fixed   |
# 121.3643683498822
#
# Name : GP regression
# Objective : 43.35350466094246
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.RatQuad.variance          |  1.1699735924301424  |      +ve      |
#   mul.RatQuad.lengthscale       |  0.9820314974444739  |      +ve      |
#   mul.RatQuad.power             |  2.0035323231211475  |      +ve      |
#   mul.std_periodic.variance     |  1.1699735924301424  |      +ve      |
#   mul.std_periodic.period       |  0.7965698601369754  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.8122615209721472  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 60.29806360108423
#
# Name : GP regression
# Objective : 19.751824092142936
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |     2.535446348750728  |               |
#   mul.RatQuad.variance         |    0.4485665673611166  |      +ve      |
#   mul.RatQuad.lengthscale      |   0.34530211346089534  |      +ve      |
#   mul.RatQuad.power            |    2.4246854314422137  |      +ve      |
#   mul.Exponential.variance     |   0.44856656736111644  |      +ve      |
#   mul.Exponential.lengthscale  |  0.005948156649501792  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 116.34082047906236
#
# Name : GP regression
# Objective : 42.57459867693241
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.RatQuad.variance         |  1.0291734376540784  |      +ve      |
#   mul.RatQuad.lengthscale      |  1.0078688569667376  |      +ve      |
#   mul.RatQuad.power            |  1.9956651240667203  |      +ve      |
#   mul.Exponential.variance     |  1.0291734376540784  |      +ve      |
#   mul.Exponential.lengthscale  |   0.993879869376247  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 56.83232770749831
#
# Name : GP regression
# Objective : 19.751824096749836
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |     2.535447878987486  |               |
#   mul.Mat32.variance       |    0.4485671594503925  |      +ve      |
#   mul.Mat32.lengthscale    |  0.008863874269663775  |      +ve      |
#   mul.rbf.variance         |    0.4485671594503947  |      +ve      |
#   mul.rbf.lengthscale      |    0.5769938371586388  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 118.16469189093434
#
# Name : GP regression
# Objective : 45.21940233426826
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  1.3561134625242353  |      +ve      |
#   mul.Mat32.lengthscale    |  0.5265666913068714  |      +ve      |
#   mul.rbf.variance         |  1.3561134625242353  |      +ve      |
#   mul.rbf.lengthscale      |  0.8583525611201466  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 60.29806368291864
#
# Name : GP regression
# Objective : 19.75182413306014
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354328728077213  |               |
#   mul.Mat32.variance       |   0.44857631482222904  |      +ve      |
#   mul.Mat32.lengthscale    |  0.009499377905312623  |      +ve      |
#   mul.RatQuad.variance     |    0.4485763148222316  |      +ve      |
#   mul.RatQuad.lengthscale  |   0.10942313242540351  |      +ve      |
#   mul.RatQuad.power        |    2.7442415096275474  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 121.49964094629067
#
# Name : GP regression
# Objective : 45.154008910546565
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  1.3377877324852963  |      +ve      |
#   mul.Mat32.lengthscale    |  0.6116509660059735  |      +ve      |
#   mul.RatQuad.variance     |  1.3377877324852963  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.7694854373914864  |      +ve      |
#   mul.RatQuad.power        |  2.1121938857578693  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 56.8323277201785
#
# Name : GP regression
# Objective : 19.75182410308993
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354469571926823  |               |
#   mul.Mat32.variance       |    0.4485652950228195  |      +ve      |
#   mul.Mat32.lengthscale    |  0.016387970596369518  |      +ve      |
#   mul.Mat32_1.variance     |    0.4485652950228195  |      +ve      |
#   mul.Mat32_1.lengthscale  |  0.016387970596369518  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 119.21023145287846
#
# Name : GP regression
# Objective : 45.74217211524032
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  1.2432601462642543  |      +ve      |
#   mul.Mat32.lengthscale    |   0.779838355365897  |      +ve      |
#   mul.Mat32_1.variance     |  1.2432601462642543  |      +ve      |
#   mul.Mat32_1.lengthscale  |   0.779838355365897  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 56.832327773788975
#
# Name : GP regression
# Objective : 19.75182412989517
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    2.535449967974341  |               |
#   mul.Mat32.variance       |  0.44856840167922046  |      +ve      |
#   mul.Mat32.lengthscale    |  0.00934215233963837  |      +ve      |
#   mul.Mat52.variance       |  0.44856840167946327  |      +ve      |
#   mul.Mat52.lengthscale    |   0.2220773188540929  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 118.56388537964007
#
# Name : GP regression
# Objective : 45.41899907862113
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat32.variance       |  1.3068336560986213  |      +ve      |
#   mul.Mat32.lengthscale    |  0.6345940964649817  |      +ve      |
#   mul.Mat52.variance       |  1.3068336560986213  |      +ve      |
#   mul.Mat52.lengthscale    |  0.8069183579925645  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 38.569629698051585
#
# Name : GP regression
# Objective : 8.887607140626613
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   constmap.C                    |  2.5248318769423106  |               |
#   mul.Mat32.variance            |  0.4805372974040289  |      +ve      |
#   mul.Mat32.lengthscale         |   3645.066167962672  |      +ve      |
#   mul.std_periodic.variance     |  0.4805372974039077  |      +ve      |
#   mul.std_periodic.period       |  0.6923199253548371  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.5388366974642879  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 115.81065048492854
#
# Name : GP regression
# Objective : 42.3095136798655
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.Mat32.variance            |  1.0398467286447413  |      +ve      |
#   mul.Mat32.lengthscale         |  0.9861436349682728  |      +ve      |
#   mul.std_periodic.variance     |  1.0398467286447413  |      +ve      |
#   mul.std_periodic.period       |  0.9483749977691034  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9484670021140044  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 56.83232770859141
#
# Name : GP regression
# Objective : 19.751824097296385
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |    2.5354465184137815  |               |
#   mul.Mat32.variance           |    0.4485672530451048  |      +ve      |
#   mul.Mat32.lengthscale        |   0.29517613984813573  |      +ve      |
#   mul.Exponential.variance     |    0.4485672530451045  |      +ve      |
#   mul.Exponential.lengthscale  |  0.006040877625085154  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 109.09524074110647
#
# Name : GP regression
# Objective : 40.684676759354325
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Mat32.variance           |  1.0054533238316357  |      +ve      |
#   mul.Mat32.lengthscale        |  1.0039698767664356  |      +ve      |
#   mul.Exponential.variance     |  1.0054533238316357  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9967726412729095  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 56.83232775044422
#
# Name : GP regression
# Objective : 19.751824118222796
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354494668852254  |               |
#   mul.Mat52.variance       |    0.4485675473863079  |      +ve      |
#   mul.Mat52.lengthscale    |  0.010678205685017851  |      +ve      |
#   mul.rbf.variance         |    0.4485675473863016  |      +ve      |
#   mul.rbf.lengthscale      |    0.5492602650204232  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 116.53734269138165
#
# Name : GP regression
# Objective : 44.40572773449192
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   linmap.A                 |               (4, 1)  |               |
#   mul.Mat52.variance       |   1.3703236055871253  |      +ve      |
#   mul.Mat52.lengthscale    |  0.39989967548978855  |      +ve      |
#   mul.rbf.variance         |   1.3703236055871253  |      +ve      |
#   mul.rbf.lengthscale      |   0.7332782387350558  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 60.29806395004595
#
# Name : GP regression
# Objective : 19.751824266623796
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |     2.535430474876845  |               |
#   mul.Mat52.variance       |   0.44858935951963563  |      +ve      |
#   mul.Mat52.lengthscale    |   0.07075574889893947  |      +ve      |
#   mul.RatQuad.variance     |      0.44858935951964  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.007875124991840126  |      +ve      |
#   mul.RatQuad.power        |     3.360050038251125  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 120.02920191505598
#
# Name : GP regression
# Objective : 44.41878939492922
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat52.variance       |  1.3578799976511182  |      +ve      |
#   mul.Mat52.lengthscale    |  0.5761637472203005  |      +ve      |
#   mul.RatQuad.variance     |  1.3578799976511182  |      +ve      |
#   mul.RatQuad.lengthscale  |  0.5589395999320718  |      +ve      |
#   mul.RatQuad.power        |   2.228190568142513  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 56.83232777361988
#
# Name : GP regression
# Objective : 19.751824129810625
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |    2.5354498360478632  |               |
#   mul.Mat52.variance       |     0.448568365622781  |      +ve      |
#   mul.Mat52.lengthscale    |   0.22207667876396103  |      +ve      |
#   mul.Mat32.variance       |   0.44856836562265295  |      +ve      |
#   mul.Mat32.lengthscale    |  0.009342018300023586  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 111.25637091561143
#
# Name : GP regression
# Objective : 41.765241846606806
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   linmap.A                 |               (4, 1)  |               |
#   mul.Mat52.variance       |    1.113123263759517  |      +ve      |
#   mul.Mat52.lengthscale    |   0.7043392488219603  |      +ve      |
#   mul.Mat32.variance       |    1.113123263759517  |      +ve      |
#   mul.Mat32.lengthscale    |  0.39094171376779113  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
# 56.832327705364634
#
# Name : GP regression
# Objective : 19.751824095683
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.           |                 value  |  constraints  |  priors
#   constmap.C               |     2.535447566186878  |               |
#   mul.Mat52.variance       |   0.44856681212996835  |      +ve      |
#   mul.Mat52.lengthscale    |  0.018152834849107822  |      +ve      |
#   mul.Mat52_1.variance     |   0.44856681212996835  |      +ve      |
#   mul.Mat52_1.lengthscale  |  0.018152834849107822  |      +ve      |
#   Gaussian_noise.variance  |                 1e-06  |   +ve fixed   |
# 115.93795067530796
#
# Name : GP regression
# Objective : 44.10603172645507
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.           |               value  |  constraints  |  priors
#   linmap.A                 |              (4, 1)  |               |
#   mul.Mat52.variance       |  1.3702730922530726  |      +ve      |
#   mul.Mat52.lengthscale    |  0.5704862272747341  |      +ve      |
#   mul.Mat52_1.variance     |  1.3702730922530726  |      +ve      |
#   mul.Mat52_1.lengthscale  |  0.5704862272747341  |      +ve      |
#   Gaussian_noise.variance  |               1e-06  |   +ve fixed   |
# 38.5411332371133
#
# Name : GP regression
# Objective : 8.87335891015747
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   2.5504216429832285  |               |
#   mul.Mat52.variance            |   0.4763164981212678  |      +ve      |
#   mul.Mat52.lengthscale         |   3336.8301090527493  |      +ve      |
#   mul.std_periodic.variance     |  0.47631649812401217  |      +ve      |
#   mul.std_periodic.period       |   0.6923198331374633  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5365169171972448  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 111.03130314565068
#
# Name : GP regression
# Objective : 39.91984001022657
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.Mat52.variance            |   1.048035887877775  |      +ve      |
#   mul.Mat52.lengthscale         |  0.9893332412939331  |      +ve      |
#   mul.std_periodic.variance     |   1.048035887877775  |      +ve      |
#   mul.std_periodic.period       |  0.8746080504882774  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.867566572420892  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 56.8323277357475
#
# Name : GP regression
# Objective : 19.75182411087443
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |    2.5354462764933654  |               |
#   mul.Mat52.variance           |   0.44856871963692735  |      +ve      |
#   mul.Mat52.lengthscale        |   0.46331156137297536  |      +ve      |
#   mul.Exponential.variance     |     0.448568719636934  |      +ve      |
#   mul.Exponential.lengthscale  |  0.006159703944794219  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 105.2745955082637
#
# Name : GP regression
# Objective : 38.77435414293294
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Mat52.variance           |  0.9999999999956093  |      +ve      |
#   mul.Mat52.lengthscale        |  1.0000000000008697  |      +ve      |
#   mul.Exponential.variance     |  0.9999999999956093  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999999999962024  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 38.61997922187954
#
# Name : GP regression
# Objective : 8.91278190254059
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   constmap.C                    |  2.5546044487220554  |               |
#   mul.std_periodic.variance     |  0.4781380191338992  |      +ve      |
#   mul.std_periodic.period       |   0.692319524169228  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.5336986510539704  |      +ve      |
#   mul.rbf.variance              |  0.4781380191279294  |      +ve      |
#   mul.rbf.lengthscale           |  3004.1282129516285  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 107.81557582098314
#
# Name : GP regression
# Objective : 38.3119763478928
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |   1.083418868978608  |      +ve      |
#   mul.std_periodic.period       |  0.7508775304874229  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.6749267682303031  |      +ve      |
#   mul.rbf.variance              |   1.083418868978608  |      +ve      |
#   mul.rbf.lengthscale           |  0.9662072597499713  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 45.24102793624134
#
# Name : GP regression
# Objective : 10.490438308321625
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    2.449276145580121  |               |
#   mul.std_periodic.variance     |  0.47929019671014395  |      +ve      |
#   mul.std_periodic.period       |   0.6923310647461157  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5376342603135523  |      +ve      |
#   mul.RatQuad.variance          |   0.4792901967101405  |      +ve      |
#   mul.RatQuad.lengthscale       |   11.783425794833976  |      +ve      |
#   mul.RatQuad.power             |  0.04733302238028618  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 111.16112694947844
#
# Name : GP regression
# Objective : 38.25188396074059
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  1.0486957703716366  |      +ve      |
#   mul.std_periodic.period       |  0.7857668570587684  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.7893159081484391  |      +ve      |
#   mul.RatQuad.variance          |  1.0486957703716366  |      +ve      |
#   mul.RatQuad.lengthscale       |  0.9714925677120547  |      +ve      |
#   mul.RatQuad.power             |  2.0087788444573444  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 36.64096117386075
#
# Name : GP regression
# Objective : 7.923272878531197
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |    2.461766072845119  |               |
#   mul.std_periodic.variance     |  0.46982397048318436  |      +ve      |
#   mul.std_periodic.period       |   0.6659199667226668  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5324411671948761  |      +ve      |
#   mul.Mat32.variance            |  0.46982397048026825  |      +ve      |
#   mul.Mat32.lengthscale         |   4770.0445730280535  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 108.64114448312844
#
# Name : GP regression
# Objective : 38.72476067896545
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  1.0147718477496452  |      +ve      |
#   mul.std_periodic.period       |  0.9206866252164143  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.9199007884313934  |      +ve      |
#   mul.Mat32.variance            |  1.0147718477496452  |      +ve      |
#   mul.Mat32.lengthscale         |  0.9863324365564853  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 38.56086743502641
#
# Name : GP regression
# Objective : 8.883226009114026
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   2.5656672102477267  |               |
#   mul.std_periodic.variance     |   0.4690162554054158  |      +ve      |
#   mul.std_periodic.period       |   0.6923200147795019  |      +ve      |
#   mul.std_periodic.lengthscale  |   0.5329414511810011  |      +ve      |
#   mul.Mat52.variance            |  0.46901625540397784  |      +ve      |
#   mul.Mat52.lengthscale         |   3223.2501807920917  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 108.29309531206547
#
# Name : GP regression
# Objective : 38.55073609343397
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |  1.0266372195146816  |      +ve      |
#   mul.std_periodic.period       |  0.8865418993304544  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.8755829013138294  |      +ve      |
#   mul.Mat52.variance            |  1.0266372195146816  |      +ve      |
#   mul.Mat52.lengthscale         |  0.9837731248638252  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 539.8347843927118
#
# Name : GP regression
# Objective : 257.78731653655683
# Number of Parameters : 8
# Number of Optimization Parameters : 7
# Updates : True
# Parameters:
#   GP_regression.                  |               value  |  constraints  |  priors
#   constmap.C                      |   2.565667208070324  |               |
#   mul.std_periodic.variance       |   1.000000971559074  |      +ve      |
#   mul.std_periodic.period         |  1.0000345195486635  |      +ve      |
#   mul.std_periodic.lengthscale    |  0.9999975590603406  |      +ve      |
#   mul.std_periodic_1.variance     |   1.000000971559074  |      +ve      |
#   mul.std_periodic_1.period       |  1.0000345195486635  |      +ve      |
#   mul.std_periodic_1.lengthscale  |  0.9999975590603406  |      +ve      |
#   Gaussian_noise.variance         |               1e-06  |   +ve fixed   |
# 82077.15753144864
#
# Name : GP regression
# Objective : 41021.25008621032
# Number of Parameters : 11
# Number of Optimization Parameters : 10
# Updates : True
# Parameters:
#   GP_regression.                  |               value  |  constraints  |  priors
#   linmap.A                        |              (4, 1)  |               |
#   mul.std_periodic.variance       |  1.0000000004925225  |      +ve      |
#   mul.std_periodic.period         |  0.9999960830655912  |      +ve      |
#   mul.std_periodic.lengthscale    |  0.9999999992736417  |      +ve      |
#   mul.std_periodic_1.variance     |  1.0000000004925225  |      +ve      |
#   mul.std_periodic_1.period       |  0.9999960830655912  |      +ve      |
#   mul.std_periodic_1.lengthscale  |  0.9999999992736417  |      +ve      |
#   Gaussian_noise.variance         |               1e-06  |   +ve fixed   |
# 53.28550679113633
#
# Name : GP regression
# Objective : 16.245545687168985
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   2.5478219864010523  |               |
#   mul.std_periodic.variance     |   0.4554787014534444  |      +ve      |
#   mul.std_periodic.period       |  0.43321242562317674  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.16885143908607353  |      +ve      |
#   mul.Exponential.variance      |  0.45547870142584884  |      +ve      |
#   mul.Exponential.lengthscale   |    2527.479264993386  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 104.40973672141402
#
# Name : GP regression
# Objective : 36.60905679810824
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.std_periodic.variance     |   0.975687464670802  |      +ve      |
#   mul.std_periodic.period       |   0.999672845990746  |      +ve      |
#   mul.std_periodic.lengthscale  |  1.0045475232126977  |      +ve      |
#   mul.Exponential.variance      |   0.975687464670802  |      +ve      |
#   mul.Exponential.lengthscale   |  1.0037422766719384  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 56.83232772569208
#
# Name : GP regression
# Objective : 19.751824105846726
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |     2.535447826163377  |               |
#   mul.Exponential.variance     |    0.4485675098721541  |      +ve      |
#   mul.Exponential.lengthscale  |  0.006101839122186467  |      +ve      |
#   mul.rbf.variance             |   0.44856750987215305  |      +ve      |
#   mul.rbf.lengthscale          |    0.6620474416995812  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 101.59909200879939
#
# Name : GP regression
# Objective : 36.936602393200786
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.9999999999972806  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999999999986313  |      +ve      |
#   mul.rbf.variance             |  0.9999999999972806  |      +ve      |
#   mul.rbf.lengthscale          |  1.0000000000002065  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 60.29806379268841
#
# Name : GP regression
# Objective : 19.751824187945026
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |     2.535451603508071  |               |
#   mul.Exponential.variance     |   0.44858397625188773  |      +ve      |
#   mul.Exponential.lengthscale  |  0.006408402754202721  |      +ve      |
#   mul.RatQuad.variance         |    0.4485839762516843  |      +ve      |
#   mul.RatQuad.lengthscale      |   0.36313303782140977  |      +ve      |
#   mul.RatQuad.power            |     2.405401187462051  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 105.16987871701443
#
# Name : GP regression
# Objective : 36.989127795908445
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.9999999999971001  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999999999989755  |      +ve      |
#   mul.RatQuad.variance         |  0.9999999999971001  |      +ve      |
#   mul.RatQuad.lengthscale      |  1.0000000000002331  |      +ve      |
#   mul.RatQuad.power            |  1.9999999999998626  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 56.832363792032496
#
# Name : GP regression
# Objective : 19.751842139016933
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                value  |  constraints  |  priors
#   constmap.C                   |   2.5354538413209657  |               |
#   mul.Exponential.variance     |  0.44855712972036443  |      +ve      |
#   mul.Exponential.lengthscale  |  0.00960778051899801  |      +ve      |
#   mul.Mat32.variance           |   0.4485571297203703  |      +ve      |
#   mul.Mat32.lengthscale        |  0.33326875947413864  |      +ve      |
#   Gaussian_noise.variance      |                1e-06  |   +ve fixed   |
# 101.58619021968511
#
# Name : GP regression
# Objective : 36.930151498643646
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.9999999999969096  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999999999991431  |      +ve      |
#   mul.Mat32.variance           |  0.9999999999969096  |      +ve      |
#   mul.Mat32.lengthscale        |  1.0000000000001579  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 56.83232845389658
#
# Name : GP regression
# Objective : 19.751824469948975
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.               |                 value  |  constraints  |  priors
#   constmap.C                   |    2.5354471913847103  |               |
#   mul.Exponential.variance     |    0.4485672604182894  |      +ve      |
#   mul.Exponential.lengthscale  |  0.007126017269322364  |      +ve      |
#   mul.Mat52.variance           |   0.44856726041843875  |      +ve      |
#   mul.Mat52.lengthscale        |     0.457033332627875  |      +ve      |
#   Gaussian_noise.variance      |                 1e-06  |   +ve fixed   |
# 101.62903605147241
#
# Name : GP regression
# Objective : 36.9515744145373
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.               |               value  |  constraints  |  priors
#   linmap.A                     |              (4, 1)  |               |
#   mul.Exponential.variance     |  0.9999999999971272  |      +ve      |
#   mul.Exponential.lengthscale  |  0.9999999999988695  |      +ve      |
#   mul.Mat52.variance           |  0.9999999999971272  |      +ve      |
#   mul.Mat52.lengthscale        |   1.000000000000191  |      +ve      |
#   Gaussian_noise.variance      |               1e-06  |   +ve fixed   |
# 60.297980102946084
#
# Name : GP regression
# Objective : 19.751782343073863
# Number of Parameters : 7
# Number of Optimization Parameters : 6
# Updates : True
# Parameters:
#   GP_regression.                |                value  |  constraints  |  priors
#   constmap.C                    |   2.5354528784045205  |               |
#   mul.Exponential.variance      |  0.44856686213897967  |      +ve      |
#   mul.Exponential.lengthscale   |   0.2191297009952866  |      +ve      |
#   mul.std_periodic.variance     |   0.4485668621389808  |      +ve      |
#   mul.std_periodic.period       |   0.1857394236331609  |      +ve      |
#   mul.std_periodic.lengthscale  |  0.07106653028028795  |      +ve      |
#   Gaussian_noise.variance       |                1e-06  |   +ve fixed   |
# 104.82729779957265
#
# Name : GP regression
# Objective : 36.817837337187555
# Number of Parameters : 10
# Number of Optimization Parameters : 9
# Updates : True
# Parameters:
#   GP_regression.                |               value  |  constraints  |  priors
#   linmap.A                      |              (4, 1)  |               |
#   mul.Exponential.variance      |  0.9999999999952003  |      +ve      |
#   mul.Exponential.lengthscale   |   1.000000000000201  |      +ve      |
#   mul.std_periodic.variance     |  0.9999999999952003  |      +ve      |
#   mul.std_periodic.period       |  0.9999999999998466  |      +ve      |
#   mul.std_periodic.lengthscale  |  1.0000000000006064  |      +ve      |
#   Gaussian_noise.variance       |               1e-06  |   +ve fixed   |
# 56.832337788797076
#
# Name : GP regression
# Objective : 19.75182913739922
# Number of Parameters : 6
# Number of Optimization Parameters : 5
# Updates : True
# Parameters:
#   GP_regression.                 |                 value  |  constraints  |  priors
#   constmap.C                     |     2.535408921098021  |               |
#   mul.Exponential.variance       |    0.4485888160316251  |      +ve      |
#   mul.Exponential.lengthscale    |  0.017039721991512005  |      +ve      |
#   mul.Exponential_1.variance     |    0.4485888160316251  |      +ve      |
#   mul.Exponential_1.lengthscale  |  0.017039721991512005  |      +ve      |
#   Gaussian_noise.variance        |                 1e-06  |   +ve fixed   |
# 101.2167679644046
#
# Name : GP regression
# Objective : 36.74544037100339
# Number of Parameters : 9
# Number of Optimization Parameters : 8
# Updates : True
# Parameters:
#   GP_regression.                 |               value  |  constraints  |  priors
#   linmap.A                       |              (4, 1)  |               |
#   mul.Exponential.variance       |  0.9999999999984336  |      +ve      |
#   mul.Exponential.lengthscale    |  1.0000000000001747  |      +ve      |
#   mul.Exponential_1.variance     |  0.9999999999984336  |      +ve      |
#   mul.Exponential_1.lengthscale  |  1.0000000000001747  |      +ve      |
#   Gaussian_noise.variance        |               1e-06  |   +ve fixed   |
# 36.64096117386075 (<GPy.kern.src.prod.Prod object at 0x735dd3312650>, <GPy.models.gp_regression.GPRegression object at 0x735dd33def50>)

# %%
def best_kernel_search(X, y):
    
    kernel = GPy.kern.Matern52(input_dim=X.shape[1], variance = 1.0, lengthscale= 1.0)
    mean = GPy.mappings.Constant(input_dim = X.shape[1], output_dim = 1, value = np.mean(y))
    model = GPy.models.GPRegression(X, y, kernel, noise_var=0.001**2, mean_function=mean)
    model.Gaussian_noise.variance.fix()
    model.optimize_restarts(100, verbose=False)

    n = model.num_data
    k = len(model.optimizer_array)
    log_likelihood = model.log_likelihood()
    
    bic = k * np.log(n) - 2 * log_likelihood
    print(bic)
    print(model)

    return model

# %%
store = best_kernel_search(X, y)
# Out:
# 49.90085589327253
#
# Name : GP regression
# Objective : 19.751824092436674
# Number of Parameters : 4
# Number of Optimization Parameters : 3
# Updates : True
# Parameters:
#   GP_regression.           |                value  |  constraints  |  priors
#   constmap.C               |    2.535446936958904  |               |
#   Mat52.variance           |    0.201212187950071  |      +ve      |
#   Mat52.lengthscale        |  0.01025308967130644  |      +ve      |
#   Gaussian_noise.variance  |                1e-06  |   +ve fixed   |
